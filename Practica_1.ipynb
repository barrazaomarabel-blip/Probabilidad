# %% [markdown]
# <a href="https://colab.research.google.com/github/barrazaomarabel-blip/Probabilidad/blob/main/Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Proababilidad y estadistica
# ** Unidad 1
# ## Practica 1: ## Estadistica descriptiva e histogramas

# %%
# Lista de calificaciones del grupo a de probabilidad y estadistica
grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupoa)
type(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# list

# %%
# Sacar la medida de las calificaciones con una formula
promedio = sum(grupoa) / len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
from statistics import mean
# Utilizar la funcion mean que esta en la libreria statistics para sacar
# el promedio
promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333

# %%
# Definamos una variable llamada tiempos100mts de tipo lista, que contiene los
# tiempos que tardaron los 10 alumnos para correr los 100 metros
tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65,
                 15.10, 17.20]

# Desplegamos los valores de la lista
print(tiempos100mts)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
# Libreria de paython para graficar valores
import matplotlib.pyplot as plt
plt.hist(grupoa) # Se cambió 'fabrica1' por 'grupoa'
plt.title("produccion diaria de la fabrica 1")

plt.text(0.5, 1.0, "produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la fabrica 1')
