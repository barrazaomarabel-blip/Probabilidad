# %% [markdown]
# <a href="https://colab.research.google.com/github/barrazaomarabel-blip/Probabilidad/blob/main/Unidad%201%20/Practica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Probabilidad y estadistica**
#
# ## **Unidad 1**
#
# ### **Practica 3. Tabla de frecuencias y regla de sturges..**
#
# ### Docente: *Dr. Jose Gabriel Rodriguez Rivas*
#
# ### Alumno: *Omar Abel Barraza Valverde*

# %%
# basado  en el LIBRO estadistica para administracion pagina 12
# creamos una lista vacia que representa la edad de 100 personas
import random
edades = []
# Hacemos un ciclo para generar 100 numeros aleatorios qe representan la edad de las personas
for i in range(100):
  # generamos un numero aleatorio con la funcion randint y lo guardamos en la variable
  # numero_aleatorio
  numero_aleatorio = random.randint( 18, 70)
  # Agregamos el numero aleatorio a la lista de valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [63, 48, 54, 30, 39, 66, 30, 65, 26, 69, 34, 24, 49, 40, 31, 56, 52, 60, 46, 22, 65, 69, 47, 62, 59, 39, 23, 40, 29, 68, 43, 70, 42, 45, 18, 56, 53, 39, 55, 25, 60, 38, 70, 40, 65, 66, 20, 69, 52, 24, 22, 39, 36, 70, 59, 40, 61, 67, 44, 64, 23, 44, 45, 58, 23, 42, 65, 70, 21, 38, 56, 65, 70, 25, 37, 55, 37, 29, 52, 62, 27, 18, 52, 29, 60, 38, 56, 65, 56, 60, 41, 51, 63, 55, 55, 37, 41, 57, 23, 26]

# %%
import pandas as pd

# %%
import pandas as pd
# Crear un DataFrame de pandas con los numeros aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    63
# 1    48
# 2    54
# 3    30
# 4    39

# %%
# Calcular la tabla de distribucion de frecuencias
tabla_frecuencias = df[ 'Edad' ].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribucion de frecuencias
print("Tabla de Distribucion de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribucion de Frecuencias:
#     Edad  Frecuencia
# 23    18           2
# 37    20           1
# 43    21           1
# 26    22           2
# 4     23           4
# 22    24           2
# 19    25           2
# 21    26           2
# 44    27           1
# 9     29           3
# 13    30           2
# 31    31           1
# 29    34           1
# 38    36           1
# 11    37           3
# 10    38           3
# 6     39           4
# 3     40           4
# 18    41           2
# 16    42           2
# 36    43           1
# 15    44           2
# 17    45           2
# 35    46           1
# 34    47           1
# 30    48           1
# 28    49           1
# 45    51           1
# 5     52           4
# 32    53           1
# 27    54           1
# 8     55           4
# 1     56           5
# 46    57           1
# 41    58           1
# 25    59           2
# 7     60           4
# 40    61           1
# 24    62           2
# 14    63           2
# 42    64           1
# 0     65           6
# 20    66           2
# 39    67           1
# 33    68           1
# 12    69           3
# 2     70           5

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 23    18           2           0.02
# 37    20           1           0.01
# 43    21           1           0.01
# 26    22           2           0.02
# 4     23           4           0.04
# 22    24           2           0.02
# 19    25           2           0.02
# 21    26           2           0.02
# 44    27           1           0.01
# 9     29           3           0.03
# 13    30           2           0.02
# 31    31           1           0.01
# 29    34           1           0.01
# 38    36           1           0.01
# 11    37           3           0.03
# 10    38           3           0.03
# 6     39           4           0.04
# 3     40           4           0.04
# 18    41           2           0.02
# 16    42           2           0.02
# 36    43           1           0.01
# 15    44           2           0.02
# 17    45           2           0.02
# 35    46           1           0.01
# 34    47           1           0.01
# 30    48           1           0.01
# 28    49           1           0.01
# 45    51           1           0.01
# 5     52           4           0.04
# 32    53           1           0.01
# 27    54           1           0.01
# 8     55           4           0.04
# 1     56           5           0.05
# 46    57           1           0.01
# 41    58           1           0.01
# 25    59           2           0.02
# 7     60           4           0.04
# 40    61           1           0.01
# 24    62           2           0.02
# 14    63           2           0.02
# 42    64           1           0.01
# 0     65           6           0.06
# 20    66           2           0.02
# 39    67           1           0.01
# 33    68           1           0.01
# 12    69           3           0.03
# 2     70           5           0.05

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 23    18           2           0.02              2.0
# 37    20           1           0.01              1.0
# 43    21           1           0.01              1.0
# 26    22           2           0.02              2.0
# 4     23           4           0.04              4.0
# 22    24           2           0.02              2.0
# 19    25           2           0.02              2.0
# 21    26           2           0.02              2.0
# 44    27           1           0.01              1.0
# 9     29           3           0.03              3.0
# 13    30           2           0.02              2.0
# 31    31           1           0.01              1.0
# 29    34           1           0.01              1.0
# 38    36           1           0.01              1.0
# 11    37           3           0.03              3.0
# 10    38           3           0.03              3.0
# 6     39           4           0.04              4.0
# 3     40           4           0.04              4.0
# 18    41           2           0.02              2.0
# 16    42           2           0.02              2.0
# 36    43           1           0.01              1.0
# 15    44           2           0.02              2.0
# 17    45           2           0.02              2.0
# 35    46           1           0.01              1.0
# 34    47           1           0.01              1.0
# 30    48           1           0.01              1.0
# 28    49           1           0.01              1.0
# 45    51           1           0.01              1.0
# 5     52           4           0.04              4.0
# 32    53           1           0.01              1.0
# 27    54           1           0.01              1.0
# 8     55           4           0.04              4.0
# 1     56           5           0.05              5.0
# 46    57           1           0.01              1.0
# 41    58           1           0.01              1.0
# 25    59           2           0.02              2.0
# 7     60           4           0.04              4.0
# 40    61           1           0.01              1.0
# 24    62           2           0.02              2.0
# 14    63           2           0.02              2.0
# 42    64           1           0.01              1.0
# 0     65           6           0.06              6.0
# 20    66           2           0.02              2.0
# 39    67           1           0.01              1.0
# 33    68           1           0.01              1.0
# 12    69           3           0.03              3.0
# 2     70           5           0.05              5.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 23    18           2           0.02              2.0               2
# 37    20           1           0.01              1.0               3
# 43    21           1           0.01              1.0               4
# 26    22           2           0.02              2.0               6
# 4     23           4           0.04              4.0              10
# 22    24           2           0.02              2.0              12
# 19    25           2           0.02              2.0              14
# 21    26           2           0.02              2.0              16
# 44    27           1           0.01              1.0              17
# 9     29           3           0.03              3.0              20
# 13    30           2           0.02              2.0              22
# 31    31           1           0.01              1.0              23
# 29    34           1           0.01              1.0              24
# 38    36           1           0.01              1.0              25
# 11    37           3           0.03              3.0              28
# 10    38           3           0.03              3.0              31
# 6     39           4           0.04              4.0              35
# 3     40           4           0.04              4.0              39
# 18    41           2           0.02              2.0              41
# 16    42           2           0.02              2.0              43
# 36    43           1           0.01              1.0              44
# 15    44           2           0.02              2.0              46
# 17    45           2           0.02              2.0              48
# 35    46           1           0.01              1.0              49
# 34    47           1           0.01              1.0              50
# 30    48           1           0.01              1.0              51
# 28    49           1           0.01              1.0              52
# 45    51           1           0.01              1.0              53
# 5     52           4           0.04              4.0              57
# 32    53           1           0.01              1.0              58
# 27    54           1           0.01              1.0              59
# 8     55           4           0.04              4.0              63
# 1     56           5           0.05              5.0              68
# 46    57           1           0.01              1.0              69
# 41    58           1           0.01              1.0              70
# 25    59           2           0.02              2.0              72
# 7     60           4           0.04              4.0              76
# 40    61           1           0.01              1.0              77
# 24    62           2           0.02              2.0              79
# 14    63           2           0.02              2.0              81
# 42    64           1           0.01              1.0              82
# 0     65           6           0.06              6.0              88
# 20    66           2           0.02              2.0              90
# 39    67           1           0.01              1.0              91
# 33    68           1           0.01              1.0              92
# 12    69           3           0.03              3.0              95
# 2     70           5           0.05              5.0             100

# %%
# Importamos la libreria math de funciones matematicas
import math

# %%
# Volvemos a usar la lista edades
print(edades)
# Out:
# [63, 48, 54, 30, 39, 66, 30, 65, 26, 69, 34, 24, 49, 40, 31, 56, 52, 60, 46, 22, 65, 69, 47, 62, 59, 39, 23, 40, 29, 68, 43, 70, 42, 45, 18, 56, 53, 39, 55, 25, 60, 38, 70, 40, 65, 66, 20, 69, 52, 24, 22, 39, 36, 70, 59, 40, 61, 67, 44, 64, 23, 44, 45, 58, 23, 42, 65, 70, 21, 38, 56, 65, 70, 25, 37, 55, 37, 29, 52, 62, 27, 18, 52, 29, 60, 38, 56, 65, 56, 60, 41, 51, 63, 55, 55, 37, 41, 57, 23, 26]

# %%
# Crear un DataFrame con la edades
df = pd.DataFrame({'Edad' : edades})
df
# Out:
#     Edad
# 0     63
# 1     48
# 2     54
# 3     30
# 4     39
# ..   ...
# 95    37
# 96    41
# 97    57
# 98    23
# 99    26
#
# [100 rows x 1 columns]

# %%
# Calcular el numero de intervalos utilizando la regla de sturges
n = len(edades)
k = int( 1 + math.log2(n))
print("Valor de n = ", n, "\nNumero de intervalos =", k)
# Out:
# Valor de n =  100
# Numero de intervalos = 7

# %%
# Crear la tabla de frecuencia

tabla_frecuencia = pd.cut( df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0    (62.571, 70.0]    21
# 1  (55.143, 62.571]    16
# 2  (32.857, 40.286]    16
# 3  (17.947, 25.429]    14
# 4  (47.714, 55.143]    13
# 5  (40.286, 47.714]    11
# 6  (25.429, 32.857]     9

# %%
# Ordenar la tabla de frecuencia por el inertvalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 3  (17.947, 25.429]    14
# 6  (25.429, 32.857]     9
# 2  (32.857, 40.286]    16
# 5  (40.286, 47.714]    11
# 4  (47.714, 55.143]    13
# 1  (55.143, 62.571]    16
# 0    (62.571, 70.0]    21

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec, Porc'] = tabla_frecuencia['Frec'] / n  * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec, Porc'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec, Porc  Frec Ac  Frec Rel Ac  \
# 3  (17.947, 25.429]    14      0.14        14.0       14         0.14
# 6  (25.429, 32.857]     9      0.09         9.0       23         0.23
# 2  (32.857, 40.286]    16      0.16        16.0       39         0.39
# 5  (40.286, 47.714]    11      0.11        11.0       50         0.50
# 4  (47.714, 55.143]    13      0.13        13.0       63         0.63
# 1  (55.143, 62.571]    16      0.16        16.0       79         0.79
# 0    (62.571, 70.0]    21      0.21        21.0      100         1.00
#
#    Frec Porc Ac
# 3          14.0
# 6          23.0
# 2          39.0
# 5          50.0
# 4          63.0
# 1          79.0
# 0         100.0

# %%
import matplotlib.pyplot as plt
import random

edades = []
for i in range(100):
  numero_aleatorio = random.randint(18, 70)
  edades.append(numero_aleatorio)

plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlip con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlip con valores estandar')

# %%
import pandas as pd
import math

# Crear un DataFrame con la edades
df = pd.DataFrame({'Edad' : edades})

# Calcular el numero de intervalos utilizando la regla de sturges
n = len(edades)
k = int(1 + math.log2(n))

# Crear in histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=k, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
